# %%
import kProcessor as kp
import random

# %%
# Mimic the function in kProcessor of coversion from str_to_int
def str_to_int(kmer):
    _map = {"A":0, "C":1, "T":2, "G":3}
    strint = 0
    for n in kmer:
        curr = _map[n]
        strint = strint | curr
        strint = strint << 2
        
    return strint >> 2

def int_to_str(kmer, kSize):
    _map = {0: 'A', 1: 'C', 2: 'T', 3: 'G'}
    kmer_str = ""
    for i in range(kSize, 0, -1):
        base = (kmer >> (i*2-2)) & 3
        ch = _map[base]
        kmer_str += ch
    
    return kmer_str

# Function to match 2 kmers with common first Q*2 bits or First Q Chars
# Return bool value, True if match, False if not
def matchingKmers(kmer1_int, kmer2_int, kSize, Q):
    msk = (~(-1<<Q*2)) << (kSize*2 - Q*2)
    return ((kmer1_int ^ kmer2_int) & msk == 0)

# %% [markdown]
# ### Prepare Kmers

# %%
kSize = 10
kList_str = {}
kList = {}
kf = kp.kDataFrameMQF(kSize)
for i in range(100,1000,10):
    r = random.randint(1,50)
    kmer = int_to_str(i,kSize)
    kList_str[kmer] = r
    kList[i] = r
    kf.setCount(kmer, r)

# %% [markdown]
# ### Set virtual Qs Parameters

# %%
minQ = 4
maxQ = kSize
stepQ = 1

# %% [markdown]
# # Matching

# %%
it = kf.begin()
prev_kmer = it.getHashedKmer()
count = 1000
while it != kf.end():
    if count == 0:
        break
    else:
        count -= 1
        
    it.next()
    curr_kmer = it.getHashedKmer()
    for Q in range(maxQ, minQ, -stepQ):
        if(matchingKmers(curr_kmer, prev_kmer, kf.getkSize(), Q)):
            print("Matching Q%d %s & %s | TRUE" % (Q, int_to_str(prev_kmer, kSize),int_to_str(curr_kmer, kSize)))
        else:
            print("Matching Q%d %s & %s | FALSE" % (Q, int_to_str(prev_kmer, kSize),int_to_str(curr_kmer, kSize)))
    print("---------------------------------------")
    
    prev_kmer = curr_kmer
# Out:
# Matching Q10 AAAAAACTCA & AAAAAACTGT | FALSE
# Matching Q9 AAAAAACTCA & AAAAAACTGT | FALSE
# Matching Q8 AAAAAACTCA & AAAAAACTGT | TRUE
# Matching Q7 AAAAAACTCA & AAAAAACTGT | TRUE
# Matching Q6 AAAAAACTCA & AAAAAACTGT | TRUE
# Matching Q5 AAAAAACTCA & AAAAAACTGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAACTGT & AAAAAACGTA | FALSE
# Matching Q9 AAAAAACTGT & AAAAAACGTA | FALSE
# Matching Q8 AAAAAACTGT & AAAAAACGTA | FALSE
# Matching Q7 AAAAAACTGT & AAAAAACGTA | TRUE
# Matching Q6 AAAAAACTGT & AAAAAACGTA | TRUE
# Matching Q5 AAAAAACTGT & AAAAAACGTA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAACGTA & AAAAAATAAT | FALSE
# Matching Q9 AAAAAACGTA & AAAAAATAAT | FALSE
# Matching Q8 AAAAAACGTA & AAAAAATAAT | FALSE
# Matching Q7 AAAAAACGTA & AAAAAATAAT | FALSE
# Matching Q6 AAAAAACGTA & AAAAAATAAT | TRUE
# Matching Q5 AAAAAACGTA & AAAAAATAAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAATAAT & AAAAAATAGA | FALSE
# Matching Q9 AAAAAATAAT & AAAAAATAGA | FALSE
# Matching Q8 AAAAAATAAT & AAAAAATAGA | TRUE
# Matching Q7 AAAAAATAAT & AAAAAATAGA | TRUE
# Matching Q6 AAAAAATAAT & AAAAAATAGA | TRUE
# Matching Q5 AAAAAATAAT & AAAAAATAGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAATAGA & AAAAAATCCT | FALSE
# Matching Q9 AAAAAATAGA & AAAAAATCCT | FALSE
# Matching Q8 AAAAAATAGA & AAAAAATCCT | FALSE
# Matching Q7 AAAAAATAGA & AAAAAATCCT | TRUE
# Matching Q6 AAAAAATAGA & AAAAAATCCT | TRUE
# Matching Q5 AAAAAATAGA & AAAAAATCCT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAATCCT & AAAAAATTAA | FALSE
# Matching Q9 AAAAAATCCT & AAAAAATTAA | FALSE
# Matching Q8 AAAAAATCCT & AAAAAATTAA | FALSE
# Matching Q7 AAAAAATCCT & AAAAAATTAA | TRUE
# Matching Q6 AAAAAATCCT & AAAAAATTAA | TRUE
# Matching Q5 AAAAAATCCT & AAAAAATTAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAATTAA & AAAAAATTTT | FALSE
# Matching Q9 AAAAAATTAA & AAAAAATTTT | FALSE
# Matching Q8 AAAAAATTAA & AAAAAATTTT | TRUE
# Matching Q7 AAAAAATTAA & AAAAAATTTT | TRUE
# Matching Q6 AAAAAATTAA & AAAAAATTTT | TRUE
# Matching Q5 AAAAAATTAA & AAAAAATTTT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAATTTT & AAAAAATGCA | FALSE
# Matching Q9 AAAAAATTTT & AAAAAATGCA | FALSE
# Matching Q8 AAAAAATTTT & AAAAAATGCA | FALSE
# Matching Q7 AAAAAATTTT & AAAAAATGCA | TRUE
# Matching Q6 AAAAAATTTT & AAAAAATGCA | TRUE
# Matching Q5 AAAAAATTTT & AAAAAATGCA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAATGCA & AAAAAATGGT | FALSE
# Matching Q9 AAAAAATGCA & AAAAAATGGT | FALSE
# Matching Q8 AAAAAATGCA & AAAAAATGGT | TRUE
# Matching Q7 AAAAAATGCA & AAAAAATGGT | TRUE
# Matching Q6 AAAAAATGCA & AAAAAATGGT | TRUE
# Matching Q5 AAAAAATGCA & AAAAAATGGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAATGGT & AAAAAAGATA | FALSE
# Matching Q9 AAAAAATGGT & AAAAAAGATA | FALSE
# Matching Q8 AAAAAATGGT & AAAAAAGATA | FALSE
# Matching Q7 AAAAAATGGT & AAAAAAGATA | FALSE
# Matching Q6 AAAAAATGGT & AAAAAAGATA | TRUE
# Matching Q5 AAAAAATGGT & AAAAAAGATA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAAGATA & AAAAAAGCAT | FALSE
# Matching Q9 AAAAAAGATA & AAAAAAGCAT | FALSE
# Matching Q8 AAAAAAGATA & AAAAAAGCAT | FALSE
# Matching Q7 AAAAAAGATA & AAAAAAGCAT | TRUE
# Matching Q6 AAAAAAGATA & AAAAAAGCAT | TRUE
# Matching Q5 AAAAAAGATA & AAAAAAGCAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAAGCAT & AAAAAAGCGA | FALSE
# Matching Q9 AAAAAAGCAT & AAAAAAGCGA | FALSE
# Matching Q8 AAAAAAGCAT & AAAAAAGCGA | TRUE
# Matching Q7 AAAAAAGCAT & AAAAAAGCGA | TRUE
# Matching Q6 AAAAAAGCAT & AAAAAAGCGA | TRUE
# Matching Q5 AAAAAAGCAT & AAAAAAGCGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAAGCGA & AAAAAAGTCT | FALSE
# Matching Q9 AAAAAAGCGA & AAAAAAGTCT | FALSE
# Matching Q8 AAAAAAGCGA & AAAAAAGTCT | FALSE
# Matching Q7 AAAAAAGCGA & AAAAAAGTCT | TRUE
# Matching Q6 AAAAAAGCGA & AAAAAAGTCT | TRUE
# Matching Q5 AAAAAAGCGA & AAAAAAGTCT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAAGTCT & AAAAAAGGAA | FALSE
# Matching Q9 AAAAAAGTCT & AAAAAAGGAA | FALSE
# Matching Q8 AAAAAAGTCT & AAAAAAGGAA | FALSE
# Matching Q7 AAAAAAGTCT & AAAAAAGGAA | TRUE
# Matching Q6 AAAAAAGTCT & AAAAAAGGAA | TRUE
# Matching Q5 AAAAAAGTCT & AAAAAAGGAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAAGGAA & AAAAAAGGTT | FALSE
# Matching Q9 AAAAAAGGAA & AAAAAAGGTT | FALSE
# Matching Q8 AAAAAAGGAA & AAAAAAGGTT | TRUE
# Matching Q7 AAAAAAGGAA & AAAAAAGGTT | TRUE
# Matching Q6 AAAAAAGGAA & AAAAAAGGTT | TRUE
# Matching Q5 AAAAAAGGAA & AAAAAAGGTT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAAGGTT & AAAAACAACA | FALSE
# Matching Q9 AAAAAAGGTT & AAAAACAACA | FALSE
# Matching Q8 AAAAAAGGTT & AAAAACAACA | FALSE
# Matching Q7 AAAAAAGGTT & AAAAACAACA | FALSE
# Matching Q6 AAAAAAGGTT & AAAAACAACA | FALSE
# Matching Q5 AAAAAAGGTT & AAAAACAACA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACAACA & AAAAACAAGT | FALSE
# Matching Q9 AAAAACAACA & AAAAACAAGT | FALSE
# Matching Q8 AAAAACAACA & AAAAACAAGT | TRUE
# Matching Q7 AAAAACAACA & AAAAACAAGT | TRUE
# Matching Q6 AAAAACAACA & AAAAACAAGT | TRUE
# Matching Q5 AAAAACAACA & AAAAACAAGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACAAGT & AAAAACACTA | FALSE
# Matching Q9 AAAAACAAGT & AAAAACACTA | FALSE
# Matching Q8 AAAAACAAGT & AAAAACACTA | FALSE
# Matching Q7 AAAAACAAGT & AAAAACACTA | TRUE
# Matching Q6 AAAAACAAGT & AAAAACACTA | TRUE
# Matching Q5 AAAAACAAGT & AAAAACACTA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACACTA & AAAAACATAT | FALSE
# Matching Q9 AAAAACACTA & AAAAACATAT | FALSE
# Matching Q8 AAAAACACTA & AAAAACATAT | FALSE
# Matching Q7 AAAAACACTA & AAAAACATAT | TRUE
# Matching Q6 AAAAACACTA & AAAAACATAT | TRUE
# Matching Q5 AAAAACACTA & AAAAACATAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACATAT & AAAAACATGA | FALSE
# Matching Q9 AAAAACATAT & AAAAACATGA | FALSE
# Matching Q8 AAAAACATAT & AAAAACATGA | TRUE
# Matching Q7 AAAAACATAT & AAAAACATGA | TRUE
# Matching Q6 AAAAACATAT & AAAAACATGA | TRUE
# Matching Q5 AAAAACATAT & AAAAACATGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACATGA & AAAAACAGCT | FALSE
# Matching Q9 AAAAACATGA & AAAAACAGCT | FALSE
# Matching Q8 AAAAACATGA & AAAAACAGCT | FALSE
# Matching Q7 AAAAACATGA & AAAAACAGCT | TRUE
# Matching Q6 AAAAACATGA & AAAAACAGCT | TRUE
# Matching Q5 AAAAACATGA & AAAAACAGCT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACAGCT & AAAAACCAAA | FALSE
# Matching Q9 AAAAACAGCT & AAAAACCAAA | FALSE
# Matching Q8 AAAAACAGCT & AAAAACCAAA | FALSE
# Matching Q7 AAAAACAGCT & AAAAACCAAA | FALSE
# Matching Q6 AAAAACAGCT & AAAAACCAAA | TRUE
# Matching Q5 AAAAACAGCT & AAAAACCAAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACCAAA & AAAAACCATT | FALSE
# Matching Q9 AAAAACCAAA & AAAAACCATT | FALSE
# Matching Q8 AAAAACCAAA & AAAAACCATT | TRUE
# Matching Q7 AAAAACCAAA & AAAAACCATT | TRUE
# Matching Q6 AAAAACCAAA & AAAAACCATT | TRUE
# Matching Q5 AAAAACCAAA & AAAAACCATT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACCATT & AAAAACCCCA | FALSE
# Matching Q9 AAAAACCATT & AAAAACCCCA | FALSE
# Matching Q8 AAAAACCATT & AAAAACCCCA | FALSE
# Matching Q7 AAAAACCATT & AAAAACCCCA | TRUE
# Matching Q6 AAAAACCATT & AAAAACCCCA | TRUE
# Matching Q5 AAAAACCATT & AAAAACCCCA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACCCCA & AAAAACCCGT | FALSE
# Matching Q9 AAAAACCCCA & AAAAACCCGT | FALSE
# Matching Q8 AAAAACCCCA & AAAAACCCGT | TRUE
# Matching Q7 AAAAACCCCA & AAAAACCCGT | TRUE
# Matching Q6 AAAAACCCCA & AAAAACCCGT | TRUE
# Matching Q5 AAAAACCCCA & AAAAACCCGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACCCGT & AAAAACCTTA | FALSE
# Matching Q9 AAAAACCCGT & AAAAACCTTA | FALSE
# Matching Q8 AAAAACCCGT & AAAAACCTTA | FALSE
# Matching Q7 AAAAACCCGT & AAAAACCTTA | TRUE
# Matching Q6 AAAAACCCGT & AAAAACCTTA | TRUE
# Matching Q5 AAAAACCCGT & AAAAACCTTA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACCTTA & AAAAACCGAT | FALSE
# Matching Q9 AAAAACCTTA & AAAAACCGAT | FALSE
# Matching Q8 AAAAACCTTA & AAAAACCGAT | FALSE
# Matching Q7 AAAAACCTTA & AAAAACCGAT | TRUE
# Matching Q6 AAAAACCTTA & AAAAACCGAT | TRUE
# Matching Q5 AAAAACCTTA & AAAAACCGAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACCGAT & AAAAACCGGA | FALSE
# Matching Q9 AAAAACCGAT & AAAAACCGGA | FALSE
# Matching Q8 AAAAACCGAT & AAAAACCGGA | TRUE
# Matching Q7 AAAAACCGAT & AAAAACCGGA | TRUE
# Matching Q6 AAAAACCGAT & AAAAACCGGA | TRUE
# Matching Q5 AAAAACCGAT & AAAAACCGGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACCGGA & AAAAACTACT | FALSE
# Matching Q9 AAAAACCGGA & AAAAACTACT | FALSE
# Matching Q8 AAAAACCGGA & AAAAACTACT | FALSE
# Matching Q7 AAAAACCGGA & AAAAACTACT | FALSE
# Matching Q6 AAAAACCGGA & AAAAACTACT | TRUE
# Matching Q5 AAAAACCGGA & AAAAACTACT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACTACT & AAAAACTCAA | FALSE
# Matching Q9 AAAAACTACT & AAAAACTCAA | FALSE
# Matching Q8 AAAAACTACT & AAAAACTCAA | FALSE
# Matching Q7 AAAAACTACT & AAAAACTCAA | TRUE
# Matching Q6 AAAAACTACT & AAAAACTCAA | TRUE
# Matching Q5 AAAAACTACT & AAAAACTCAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACTCAA & AAAAACTCTT | FALSE
# Matching Q9 AAAAACTCAA & AAAAACTCTT | FALSE
# Matching Q8 AAAAACTCAA & AAAAACTCTT | TRUE
# Matching Q7 AAAAACTCAA & AAAAACTCTT | TRUE
# Matching Q6 AAAAACTCAA & AAAAACTCTT | TRUE
# Matching Q5 AAAAACTCAA & AAAAACTCTT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACTCTT & AAAAACTTCA | FALSE
# Matching Q9 AAAAACTCTT & AAAAACTTCA | FALSE
# Matching Q8 AAAAACTCTT & AAAAACTTCA | FALSE
# Matching Q7 AAAAACTCTT & AAAAACTTCA | TRUE
# Matching Q6 AAAAACTCTT & AAAAACTTCA | TRUE
# Matching Q5 AAAAACTCTT & AAAAACTTCA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACTTCA & AAAAACTTGT | FALSE
# Matching Q9 AAAAACTTCA & AAAAACTTGT | FALSE
# Matching Q8 AAAAACTTCA & AAAAACTTGT | TRUE
# Matching Q7 AAAAACTTCA & AAAAACTTGT | TRUE
# Matching Q6 AAAAACTTCA & AAAAACTTGT | TRUE
# Matching Q5 AAAAACTTCA & AAAAACTTGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACTTGT & AAAAACTGTA | FALSE
# Matching Q9 AAAAACTTGT & AAAAACTGTA | FALSE
# Matching Q8 AAAAACTTGT & AAAAACTGTA | FALSE
# Matching Q7 AAAAACTTGT & AAAAACTGTA | TRUE
# Matching Q6 AAAAACTTGT & AAAAACTGTA | TRUE
# Matching Q5 AAAAACTTGT & AAAAACTGTA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACTGTA & AAAAACGAAT | FALSE
# Matching Q9 AAAAACTGTA & AAAAACGAAT | FALSE
# Matching Q8 AAAAACTGTA & AAAAACGAAT | FALSE
# Matching Q7 AAAAACTGTA & AAAAACGAAT | FALSE
# Matching Q6 AAAAACTGTA & AAAAACGAAT | TRUE
# Matching Q5 AAAAACTGTA & AAAAACGAAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACGAAT & AAAAACGAGA | FALSE
# Matching Q9 AAAAACGAAT & AAAAACGAGA | FALSE
# Matching Q8 AAAAACGAAT & AAAAACGAGA | TRUE
# Matching Q7 AAAAACGAAT & AAAAACGAGA | TRUE
# Matching Q6 AAAAACGAAT & AAAAACGAGA | TRUE
# Matching Q5 AAAAACGAAT & AAAAACGAGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACGAGA & AAAAACGCCT | FALSE
# Matching Q9 AAAAACGAGA & AAAAACGCCT | FALSE
# Matching Q8 AAAAACGAGA & AAAAACGCCT | FALSE
# Matching Q7 AAAAACGAGA & AAAAACGCCT | TRUE
# Matching Q6 AAAAACGAGA & AAAAACGCCT | TRUE
# Matching Q5 AAAAACGAGA & AAAAACGCCT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACGCCT & AAAAACGTAA | FALSE
# Matching Q9 AAAAACGCCT & AAAAACGTAA | FALSE
# Matching Q8 AAAAACGCCT & AAAAACGTAA | FALSE
# Matching Q7 AAAAACGCCT & AAAAACGTAA | TRUE
# Matching Q6 AAAAACGCCT & AAAAACGTAA | TRUE
# Matching Q5 AAAAACGCCT & AAAAACGTAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACGTAA & AAAAACGTTT | FALSE
# Matching Q9 AAAAACGTAA & AAAAACGTTT | FALSE
# Matching Q8 AAAAACGTAA & AAAAACGTTT | TRUE
# Matching Q7 AAAAACGTAA & AAAAACGTTT | TRUE
# Matching Q6 AAAAACGTAA & AAAAACGTTT | TRUE
# Matching Q5 AAAAACGTAA & AAAAACGTTT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACGTTT & AAAAACGGCA | FALSE
# Matching Q9 AAAAACGTTT & AAAAACGGCA | FALSE
# Matching Q8 AAAAACGTTT & AAAAACGGCA | FALSE
# Matching Q7 AAAAACGTTT & AAAAACGGCA | TRUE
# Matching Q6 AAAAACGTTT & AAAAACGGCA | TRUE
# Matching Q5 AAAAACGTTT & AAAAACGGCA | TRUE
# ---------------------------------------
# Matching Q10 AAAAACGGCA & AAAAACGGGT | FALSE
# Matching Q9 AAAAACGGCA & AAAAACGGGT | FALSE
# Matching Q8 AAAAACGGCA & AAAAACGGGT | TRUE
# Matching Q7 AAAAACGGCA & AAAAACGGGT | TRUE
# Matching Q6 AAAAACGGCA & AAAAACGGGT | TRUE
# Matching Q5 AAAAACGGCA & AAAAACGGGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAACGGGT & AAAAATAATA | FALSE
# Matching Q9 AAAAACGGGT & AAAAATAATA | FALSE
# Matching Q8 AAAAACGGGT & AAAAATAATA | FALSE
# Matching Q7 AAAAACGGGT & AAAAATAATA | FALSE
# Matching Q6 AAAAACGGGT & AAAAATAATA | FALSE
# Matching Q5 AAAAACGGGT & AAAAATAATA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATAATA & AAAAATACAT | FALSE
# Matching Q9 AAAAATAATA & AAAAATACAT | FALSE
# Matching Q8 AAAAATAATA & AAAAATACAT | FALSE
# Matching Q7 AAAAATAATA & AAAAATACAT | TRUE
# Matching Q6 AAAAATAATA & AAAAATACAT | TRUE
# Matching Q5 AAAAATAATA & AAAAATACAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATACAT & AAAAATACGA | FALSE
# Matching Q9 AAAAATACAT & AAAAATACGA | FALSE
# Matching Q8 AAAAATACAT & AAAAATACGA | TRUE
# Matching Q7 AAAAATACAT & AAAAATACGA | TRUE
# Matching Q6 AAAAATACAT & AAAAATACGA | TRUE
# Matching Q5 AAAAATACAT & AAAAATACGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATACGA & AAAAATATCT | FALSE
# Matching Q9 AAAAATACGA & AAAAATATCT | FALSE
# Matching Q8 AAAAATACGA & AAAAATATCT | FALSE
# Matching Q7 AAAAATACGA & AAAAATATCT | TRUE
# Matching Q6 AAAAATACGA & AAAAATATCT | TRUE
# Matching Q5 AAAAATACGA & AAAAATATCT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATATCT & AAAAATAGAA | FALSE
# Matching Q9 AAAAATATCT & AAAAATAGAA | FALSE
# Matching Q8 AAAAATATCT & AAAAATAGAA | FALSE
# Matching Q7 AAAAATATCT & AAAAATAGAA | TRUE
# Matching Q6 AAAAATATCT & AAAAATAGAA | TRUE
# Matching Q5 AAAAATATCT & AAAAATAGAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATAGAA & AAAAATAGTT | FALSE
# Matching Q9 AAAAATAGAA & AAAAATAGTT | FALSE
# Matching Q8 AAAAATAGAA & AAAAATAGTT | TRUE
# Matching Q7 AAAAATAGAA & AAAAATAGTT | TRUE
# Matching Q6 AAAAATAGAA & AAAAATAGTT | TRUE
# Matching Q5 AAAAATAGAA & AAAAATAGTT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATAGTT & AAAAATCACA | FALSE
# Matching Q9 AAAAATAGTT & AAAAATCACA | FALSE
# Matching Q8 AAAAATAGTT & AAAAATCACA | FALSE
# Matching Q7 AAAAATAGTT & AAAAATCACA | FALSE
# Matching Q6 AAAAATAGTT & AAAAATCACA | TRUE
# Matching Q5 AAAAATAGTT & AAAAATCACA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATCACA & AAAAATCAGT | FALSE
# Matching Q9 AAAAATCACA & AAAAATCAGT | FALSE
# Matching Q8 AAAAATCACA & AAAAATCAGT | TRUE
# Matching Q7 AAAAATCACA & AAAAATCAGT | TRUE
# Matching Q6 AAAAATCACA & AAAAATCAGT | TRUE
# Matching Q5 AAAAATCACA & AAAAATCAGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATCAGT & AAAAATCCTA | FALSE
# Matching Q9 AAAAATCAGT & AAAAATCCTA | FALSE
# Matching Q8 AAAAATCAGT & AAAAATCCTA | FALSE
# Matching Q7 AAAAATCAGT & AAAAATCCTA | TRUE
# Matching Q6 AAAAATCAGT & AAAAATCCTA | TRUE
# Matching Q5 AAAAATCAGT & AAAAATCCTA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATCCTA & AAAAATCTAT | FALSE
# Matching Q9 AAAAATCCTA & AAAAATCTAT | FALSE
# Matching Q8 AAAAATCCTA & AAAAATCTAT | FALSE
# Matching Q7 AAAAATCCTA & AAAAATCTAT | TRUE
# Matching Q6 AAAAATCCTA & AAAAATCTAT | TRUE
# Matching Q5 AAAAATCCTA & AAAAATCTAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATCTAT & AAAAATCTGA | FALSE
# Matching Q9 AAAAATCTAT & AAAAATCTGA | FALSE
# Matching Q8 AAAAATCTAT & AAAAATCTGA | TRUE
# Matching Q7 AAAAATCTAT & AAAAATCTGA | TRUE
# Matching Q6 AAAAATCTAT & AAAAATCTGA | TRUE
# Matching Q5 AAAAATCTAT & AAAAATCTGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATCTGA & AAAAATCGCT | FALSE
# Matching Q9 AAAAATCTGA & AAAAATCGCT | FALSE
# Matching Q8 AAAAATCTGA & AAAAATCGCT | FALSE
# Matching Q7 AAAAATCTGA & AAAAATCGCT | TRUE
# Matching Q6 AAAAATCTGA & AAAAATCGCT | TRUE
# Matching Q5 AAAAATCTGA & AAAAATCGCT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATCGCT & AAAAATTAAA | FALSE
# Matching Q9 AAAAATCGCT & AAAAATTAAA | FALSE
# Matching Q8 AAAAATCGCT & AAAAATTAAA | FALSE
# Matching Q7 AAAAATCGCT & AAAAATTAAA | FALSE
# Matching Q6 AAAAATCGCT & AAAAATTAAA | TRUE
# Matching Q5 AAAAATCGCT & AAAAATTAAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATTAAA & AAAAATTATT | FALSE
# Matching Q9 AAAAATTAAA & AAAAATTATT | FALSE
# Matching Q8 AAAAATTAAA & AAAAATTATT | TRUE
# Matching Q7 AAAAATTAAA & AAAAATTATT | TRUE
# Matching Q6 AAAAATTAAA & AAAAATTATT | TRUE
# Matching Q5 AAAAATTAAA & AAAAATTATT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATTATT & AAAAATTCCA | FALSE
# Matching Q9 AAAAATTATT & AAAAATTCCA | FALSE
# Matching Q8 AAAAATTATT & AAAAATTCCA | FALSE
# Matching Q7 AAAAATTATT & AAAAATTCCA | TRUE
# Matching Q6 AAAAATTATT & AAAAATTCCA | TRUE
# Matching Q5 AAAAATTATT & AAAAATTCCA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATTCCA & AAAAATTCGT | FALSE
# Matching Q9 AAAAATTCCA & AAAAATTCGT | FALSE
# Matching Q8 AAAAATTCCA & AAAAATTCGT | TRUE
# Matching Q7 AAAAATTCCA & AAAAATTCGT | TRUE
# Matching Q6 AAAAATTCCA & AAAAATTCGT | TRUE
# Matching Q5 AAAAATTCCA & AAAAATTCGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATTCGT & AAAAATTTTA | FALSE
# Matching Q9 AAAAATTCGT & AAAAATTTTA | FALSE
# Matching Q8 AAAAATTCGT & AAAAATTTTA | FALSE
# Matching Q7 AAAAATTCGT & AAAAATTTTA | TRUE
# Matching Q6 AAAAATTCGT & AAAAATTTTA | TRUE
# Matching Q5 AAAAATTCGT & AAAAATTTTA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATTTTA & AAAAATTGAT | FALSE
# Matching Q9 AAAAATTTTA & AAAAATTGAT | FALSE
# Matching Q8 AAAAATTTTA & AAAAATTGAT | FALSE
# Matching Q7 AAAAATTTTA & AAAAATTGAT | TRUE
# Matching Q6 AAAAATTTTA & AAAAATTGAT | TRUE
# Matching Q5 AAAAATTTTA & AAAAATTGAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATTGAT & AAAAATTGGA | FALSE
# Matching Q9 AAAAATTGAT & AAAAATTGGA | FALSE
# Matching Q8 AAAAATTGAT & AAAAATTGGA | TRUE
# Matching Q7 AAAAATTGAT & AAAAATTGGA | TRUE
# Matching Q6 AAAAATTGAT & AAAAATTGGA | TRUE
# Matching Q5 AAAAATTGAT & AAAAATTGGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATTGGA & AAAAATGACT | FALSE
# Matching Q9 AAAAATTGGA & AAAAATGACT | FALSE
# Matching Q8 AAAAATTGGA & AAAAATGACT | FALSE
# Matching Q7 AAAAATTGGA & AAAAATGACT | FALSE
# Matching Q6 AAAAATTGGA & AAAAATGACT | TRUE
# Matching Q5 AAAAATTGGA & AAAAATGACT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATGACT & AAAAATGCAA | FALSE
# Matching Q9 AAAAATGACT & AAAAATGCAA | FALSE
# Matching Q8 AAAAATGACT & AAAAATGCAA | FALSE
# Matching Q7 AAAAATGACT & AAAAATGCAA | TRUE
# Matching Q6 AAAAATGACT & AAAAATGCAA | TRUE
# Matching Q5 AAAAATGACT & AAAAATGCAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATGCAA & AAAAATGCTT | FALSE
# Matching Q9 AAAAATGCAA & AAAAATGCTT | FALSE
# Matching Q8 AAAAATGCAA & AAAAATGCTT | TRUE
# Matching Q7 AAAAATGCAA & AAAAATGCTT | TRUE
# Matching Q6 AAAAATGCAA & AAAAATGCTT | TRUE
# Matching Q5 AAAAATGCAA & AAAAATGCTT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATGCTT & AAAAATGTCA | FALSE
# Matching Q9 AAAAATGCTT & AAAAATGTCA | FALSE
# Matching Q8 AAAAATGCTT & AAAAATGTCA | FALSE
# Matching Q7 AAAAATGCTT & AAAAATGTCA | TRUE
# Matching Q6 AAAAATGCTT & AAAAATGTCA | TRUE
# Matching Q5 AAAAATGCTT & AAAAATGTCA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATGTCA & AAAAATGTGT | FALSE
# Matching Q9 AAAAATGTCA & AAAAATGTGT | FALSE
# Matching Q8 AAAAATGTCA & AAAAATGTGT | TRUE
# Matching Q7 AAAAATGTCA & AAAAATGTGT | TRUE
# Matching Q6 AAAAATGTCA & AAAAATGTGT | TRUE
# Matching Q5 AAAAATGTCA & AAAAATGTGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAATGTGT & AAAAATGGTA | FALSE
# Matching Q9 AAAAATGTGT & AAAAATGGTA | FALSE
# Matching Q8 AAAAATGTGT & AAAAATGGTA | FALSE
# Matching Q7 AAAAATGTGT & AAAAATGGTA | TRUE
# Matching Q6 AAAAATGTGT & AAAAATGGTA | TRUE
# Matching Q5 AAAAATGTGT & AAAAATGGTA | TRUE
# ---------------------------------------
# Matching Q10 AAAAATGGTA & AAAAAGAAAT | FALSE
# Matching Q9 AAAAATGGTA & AAAAAGAAAT | FALSE
# Matching Q8 AAAAATGGTA & AAAAAGAAAT | FALSE
# Matching Q7 AAAAATGGTA & AAAAAGAAAT | FALSE
# Matching Q6 AAAAATGGTA & AAAAAGAAAT | FALSE
# Matching Q5 AAAAATGGTA & AAAAAGAAAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGAAAT & AAAAAGAAGA | FALSE
# Matching Q9 AAAAAGAAAT & AAAAAGAAGA | FALSE
# Matching Q8 AAAAAGAAAT & AAAAAGAAGA | TRUE
# Matching Q7 AAAAAGAAAT & AAAAAGAAGA | TRUE
# Matching Q6 AAAAAGAAAT & AAAAAGAAGA | TRUE
# Matching Q5 AAAAAGAAAT & AAAAAGAAGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGAAGA & AAAAAGACCT | FALSE
# Matching Q9 AAAAAGAAGA & AAAAAGACCT | FALSE
# Matching Q8 AAAAAGAAGA & AAAAAGACCT | FALSE
# Matching Q7 AAAAAGAAGA & AAAAAGACCT | TRUE
# Matching Q6 AAAAAGAAGA & AAAAAGACCT | TRUE
# Matching Q5 AAAAAGAAGA & AAAAAGACCT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGACCT & AAAAAGATAA | FALSE
# Matching Q9 AAAAAGACCT & AAAAAGATAA | FALSE
# Matching Q8 AAAAAGACCT & AAAAAGATAA | FALSE
# Matching Q7 AAAAAGACCT & AAAAAGATAA | TRUE
# Matching Q6 AAAAAGACCT & AAAAAGATAA | TRUE
# Matching Q5 AAAAAGACCT & AAAAAGATAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGATAA & AAAAAGATTT | FALSE
# Matching Q9 AAAAAGATAA & AAAAAGATTT | FALSE
# Matching Q8 AAAAAGATAA & AAAAAGATTT | TRUE
# Matching Q7 AAAAAGATAA & AAAAAGATTT | TRUE
# Matching Q6 AAAAAGATAA & AAAAAGATTT | TRUE
# Matching Q5 AAAAAGATAA & AAAAAGATTT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGATTT & AAAAAGAGCA | FALSE
# Matching Q9 AAAAAGATTT & AAAAAGAGCA | FALSE
# Matching Q8 AAAAAGATTT & AAAAAGAGCA | FALSE
# Matching Q7 AAAAAGATTT & AAAAAGAGCA | TRUE
# Matching Q6 AAAAAGATTT & AAAAAGAGCA | TRUE
# Matching Q5 AAAAAGATTT & AAAAAGAGCA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGAGCA & AAAAAGAGGT | FALSE
# Matching Q9 AAAAAGAGCA & AAAAAGAGGT | FALSE
# Matching Q8 AAAAAGAGCA & AAAAAGAGGT | TRUE
# Matching Q7 AAAAAGAGCA & AAAAAGAGGT | TRUE
# Matching Q6 AAAAAGAGCA & AAAAAGAGGT | TRUE
# Matching Q5 AAAAAGAGCA & AAAAAGAGGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGAGGT & AAAAAGCATA | FALSE
# Matching Q9 AAAAAGAGGT & AAAAAGCATA | FALSE
# Matching Q8 AAAAAGAGGT & AAAAAGCATA | FALSE
# Matching Q7 AAAAAGAGGT & AAAAAGCATA | FALSE
# Matching Q6 AAAAAGAGGT & AAAAAGCATA | TRUE
# Matching Q5 AAAAAGAGGT & AAAAAGCATA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGCATA & AAAAAGCCAT | FALSE
# Matching Q9 AAAAAGCATA & AAAAAGCCAT | FALSE
# Matching Q8 AAAAAGCATA & AAAAAGCCAT | FALSE
# Matching Q7 AAAAAGCATA & AAAAAGCCAT | TRUE
# Matching Q6 AAAAAGCATA & AAAAAGCCAT | TRUE
# Matching Q5 AAAAAGCATA & AAAAAGCCAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGCCAT & AAAAAGCCGA | FALSE
# Matching Q9 AAAAAGCCAT & AAAAAGCCGA | FALSE
# Matching Q8 AAAAAGCCAT & AAAAAGCCGA | TRUE
# Matching Q7 AAAAAGCCAT & AAAAAGCCGA | TRUE
# Matching Q6 AAAAAGCCAT & AAAAAGCCGA | TRUE
# Matching Q5 AAAAAGCCAT & AAAAAGCCGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGCCGA & AAAAAGCTCT | FALSE
# Matching Q9 AAAAAGCCGA & AAAAAGCTCT | FALSE
# Matching Q8 AAAAAGCCGA & AAAAAGCTCT | FALSE
# Matching Q7 AAAAAGCCGA & AAAAAGCTCT | TRUE
# Matching Q6 AAAAAGCCGA & AAAAAGCTCT | TRUE
# Matching Q5 AAAAAGCCGA & AAAAAGCTCT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGCTCT & AAAAAGCGAA | FALSE
# Matching Q9 AAAAAGCTCT & AAAAAGCGAA | FALSE
# Matching Q8 AAAAAGCTCT & AAAAAGCGAA | FALSE
# Matching Q7 AAAAAGCTCT & AAAAAGCGAA | TRUE
# Matching Q6 AAAAAGCTCT & AAAAAGCGAA | TRUE
# Matching Q5 AAAAAGCTCT & AAAAAGCGAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGCGAA & AAAAAGCGTT | FALSE
# Matching Q9 AAAAAGCGAA & AAAAAGCGTT | FALSE
# Matching Q8 AAAAAGCGAA & AAAAAGCGTT | TRUE
# Matching Q7 AAAAAGCGAA & AAAAAGCGTT | TRUE
# Matching Q6 AAAAAGCGAA & AAAAAGCGTT | TRUE
# Matching Q5 AAAAAGCGAA & AAAAAGCGTT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGCGTT & AAAAAGTACA | FALSE
# Matching Q9 AAAAAGCGTT & AAAAAGTACA | FALSE
# Matching Q8 AAAAAGCGTT & AAAAAGTACA | FALSE
# Matching Q7 AAAAAGCGTT & AAAAAGTACA | FALSE
# Matching Q6 AAAAAGCGTT & AAAAAGTACA | TRUE
# Matching Q5 AAAAAGCGTT & AAAAAGTACA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGTACA & AAAAAGTAGT | FALSE
# Matching Q9 AAAAAGTACA & AAAAAGTAGT | FALSE
# Matching Q8 AAAAAGTACA & AAAAAGTAGT | TRUE
# Matching Q7 AAAAAGTACA & AAAAAGTAGT | TRUE
# Matching Q6 AAAAAGTACA & AAAAAGTAGT | TRUE
# Matching Q5 AAAAAGTACA & AAAAAGTAGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGTAGT & AAAAAGTCTA | FALSE
# Matching Q9 AAAAAGTAGT & AAAAAGTCTA | FALSE
# Matching Q8 AAAAAGTAGT & AAAAAGTCTA | FALSE
# Matching Q7 AAAAAGTAGT & AAAAAGTCTA | TRUE
# Matching Q6 AAAAAGTAGT & AAAAAGTCTA | TRUE
# Matching Q5 AAAAAGTAGT & AAAAAGTCTA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGTCTA & AAAAAGTTAT | FALSE
# Matching Q9 AAAAAGTCTA & AAAAAGTTAT | FALSE
# Matching Q8 AAAAAGTCTA & AAAAAGTTAT | FALSE
# Matching Q7 AAAAAGTCTA & AAAAAGTTAT | TRUE
# Matching Q6 AAAAAGTCTA & AAAAAGTTAT | TRUE
# Matching Q5 AAAAAGTCTA & AAAAAGTTAT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGTTAT & AAAAAGTTGA | FALSE
# Matching Q9 AAAAAGTTAT & AAAAAGTTGA | FALSE
# Matching Q8 AAAAAGTTAT & AAAAAGTTGA | TRUE
# Matching Q7 AAAAAGTTAT & AAAAAGTTGA | TRUE
# Matching Q6 AAAAAGTTAT & AAAAAGTTGA | TRUE
# Matching Q5 AAAAAGTTAT & AAAAAGTTGA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGTTGA & AAAAAGTGCT | FALSE
# Matching Q9 AAAAAGTTGA & AAAAAGTGCT | FALSE
# Matching Q8 AAAAAGTTGA & AAAAAGTGCT | FALSE
# Matching Q7 AAAAAGTTGA & AAAAAGTGCT | TRUE
# Matching Q6 AAAAAGTTGA & AAAAAGTGCT | TRUE
# Matching Q5 AAAAAGTTGA & AAAAAGTGCT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGTGCT & AAAAAGGAAA | FALSE
# Matching Q9 AAAAAGTGCT & AAAAAGGAAA | FALSE
# Matching Q8 AAAAAGTGCT & AAAAAGGAAA | FALSE
# Matching Q7 AAAAAGTGCT & AAAAAGGAAA | FALSE
# Matching Q6 AAAAAGTGCT & AAAAAGGAAA | TRUE
# Matching Q5 AAAAAGTGCT & AAAAAGGAAA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGGAAA & AAAAAGGATT | FALSE
# Matching Q9 AAAAAGGAAA & AAAAAGGATT | FALSE
# Matching Q8 AAAAAGGAAA & AAAAAGGATT | TRUE
# Matching Q7 AAAAAGGAAA & AAAAAGGATT | TRUE
# Matching Q6 AAAAAGGAAA & AAAAAGGATT | TRUE
# Matching Q5 AAAAAGGAAA & AAAAAGGATT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGGATT & AAAAAGGCCA | FALSE
# Matching Q9 AAAAAGGATT & AAAAAGGCCA | FALSE
# Matching Q8 AAAAAGGATT & AAAAAGGCCA | FALSE
# Matching Q7 AAAAAGGATT & AAAAAGGCCA | TRUE
# Matching Q6 AAAAAGGATT & AAAAAGGCCA | TRUE
# Matching Q5 AAAAAGGATT & AAAAAGGCCA | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGGCCA & AAAAAGGCGT | FALSE
# Matching Q9 AAAAAGGCCA & AAAAAGGCGT | FALSE
# Matching Q8 AAAAAGGCCA & AAAAAGGCGT | TRUE
# Matching Q7 AAAAAGGCCA & AAAAAGGCGT | TRUE
# Matching Q6 AAAAAGGCCA & AAAAAGGCGT | TRUE
# Matching Q5 AAAAAGGCCA & AAAAAGGCGT | TRUE
# ---------------------------------------
# Matching Q10 AAAAAGGCGT & ACCAAAACCC | FALSE
# Matching Q9 AAAAAGGCGT & ACCAAAACCC | FALSE
# Matching Q8 AAAAAGGCGT & ACCAAAACCC | FALSE
# Matching Q7 AAAAAGGCGT & ACCAAAACCC | FALSE
# Matching Q6 AAAAAGGCGT & ACCAAAACCC | FALSE
# Matching Q5 AAAAAGGCGT & ACCAAAACCC | FALSE
# ---------------------------------------
